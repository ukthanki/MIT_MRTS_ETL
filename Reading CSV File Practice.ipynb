# %%
import pandas as pd

# %%
import csv

with open("test_csv.csv") as csv_file:
    
    csv_reader = csv.reader(csv_file, delimiter=",")
    
    for row in csv_reader:
        print(row)
# Out:
# ['first name', 'last name', 'dob']
# ['John', 'Allen', '01/01/2001']
# ['Matthew', 'Jester', '04/15/1999']
# ['Michael', 'Wilson', '09/26/2002']

# %%
import csv

with open("mrtssales92-present.xls - 2020.csv") as csv_file:
    
    csv_reader = csv.reader(csv_file, delimiter=",")
    
    for row in csv_reader:
        print(row)
# Out:
# ['Estimates of Monthly Retail and Food Services Sales by Kind of Business: 2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['[Estimates are shown in millions of dollars and are based on data from the Monthly Retail Trade Survey, Annual Retail Trade Survey, Service Annual Survey, and administrative records]', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['NAICS  Code', 'Kind of Business', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', 'Jan. 2020', 'Feb. 2020', 'Mar. 2020', 'Apr. 2020', 'May 2020', 'Jun. 2020', 'Jul. 2020', 'Aug. 2020', 'Sep. 2020', 'Oct. 2020', 'Nov. 2020', 'Dec. 2020', 'TOTAL']
# ['', 'NOT ADJUSTED', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', 'Retail and food services sales, total', '480,301', '478,467', '478,267', '407,227', '504,607', '532,678', '549,416', '545,307', '530,987', '553,114', '543,273', '611,429', '6,215,073']
# ...

# %%
df = pd.read_csv("mrtssales92-present.xls - 2020.csv", skiprows=4)

# %%
df
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 109  (1) GAFO represents stores classified in the f...
# 110  (2) Estimates are adjusted for seasonal variat...
# 111
# 112  Note: Estimates are not adjusted for price cha...
# 113  Information on sample design, estimation proce...
#
#                                             Unnamed: 1 Jan. 2020 Feb. 2020  \
# 0                                         NOT ADJUSTED       NaN       NaN
# 1                Retail and food services sales, total   480,301   478,467
# 2    Retail sales and food services excl motor vehi...   386,934   380,639
# ...
